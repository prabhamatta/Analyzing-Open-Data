# %% [markdown]
# # How to use Python for Data Analysis (PfDA)

# %% [markdown]
# *Reading Assigned a while ago from PfDA*
#
#    * read [`PfDA`, Chap 1  Preliminaries](http://proquest.safaribooksonline.com/book/programming/python/9781449323592/1dot-preliminaries/id2664030), especially the installation instructions for EPD Free for your computer platform.  I want you to try installing EPD Free (or EPD Academic) before class on Thursday.
#    * read [`PfDA`, Chap 3](http://proquest.safaribooksonline.com/book/programming/python/9781449323592/3dot-ipython-an-interactive-computing-and-development-environment/id2545624)
#    * skim [`PfDA`, Appendix: Python Language Essentials](http://proquest.safaribooksonline.com/book/programming/python/9781449323592/adot-python-language-essentials/id2819503) -- to help remind yourself of key elements of standard Python
#    * skim [`PfDA`, Chap 2 Introductory Examples](http://proquest.safaribooksonline.com/book/programming/python/9781449323592/2dot-introductory-examples/id423077)

# %% [markdown]
# * Github repo for book: [pydata/pydata-book](https://github.com/pydata/pydata-book)
# * [Confirmed Errata | O'Reilly Media Python for Data Analysis](http://www.oreilly.com/catalog/errata.csp?isbn=0636920023784)
# * [Unconfirmed Errata | O'Reilly Media Python for Data Analysis](http://www.oreilly.com/catalog/errataunconfirmed.csp?isbn=0636920023784)

# %% [markdown]
# I suggest cloning the repo somewhere on your computer
#
# my own setup: I've git cloned
#
#     https://github.com/pydata/pydata-book.git
#
# into
#
#     /Users/raymondyee/D/Document/Working_with_Open_Data/pydata-book/
#
# and put a symbolic link to /Users/raymondyee/D/Document/Working_with_Open_Data/pydata-book/ in my working-with-open-data-2014 repo parallel to the notebooks directory.

# %%
# %%bash
# # this is what I ran on my mac to make this link
# cd ..
# ln -s /Users/prabha/classes/spring2014/opendata/pydata-book pydata-book

# %%
# %%bash
# # in my case, I had been adding other notebooks
# ls ../pydata-book/
# Out:
# ch02
# ch03
# ch06
# ch07
# ch08
# ch09
# ch11
# ch13

# %% [markdown]
# # Calculate PFDA_PATH (for RY's relative dir setup) or set it manually

# %%
#http://stackoverflow.com/a/17295128/7782
import os
PFDA_PATH  = os.path.abspath(os.path.join(os.getcwd(), 
                                          os.path.join(os.path.pardir, "pydata-book")
                                        ))
PFDA_PATH
# Out:
# '/Users/prabha/programming/spring2014/opendata/raymond_working_open_data_2014/pydata-book'

# %%
assert os.path.exists(PFDA_PATH)

# %% [markdown]
# # Chapter 1

# %%
# locat the bitly file and make sure it exists
import os

path = os.path.join(PFDA_PATH,'ch02/usagov_bitly_data2012-03-16-1331923249.txt')
print "bit.ly data file exists : ", os.path.exists(path)
# Out:
# bit.ly data file exists :  True

# %%
# let's try some of the code from PfDA
# read a line
open(path).readline()
# Out:
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'

# %%
import json
records = [json.loads(line) for line in open(path)]

# %%
len(records)
records
# Out:
# [{u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Danvers',
#   u'g': u'A6qOVH',
#   u'gr': u'MA',
#   u'h': u'wfLQtf',
#   u'hc': 1331822918,
#   u'hh': u'1.usa.gov',
#   u'l': u'orofrog',
#   u'll': [42.576698, -70.954903],
#   u'nk': 1,
#   u'r': u'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#   u't': 1331923247,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.ncbi.nlm.nih.gov/pubmed/22415991'},
#  {u'a': u'GoogleMaps/RochesterNY',
#   u'c': u'US',
#   u'cy': u'Provo',
#   u'g': u'mwszkS',
#   u'gr': u'UT',
#   u'h': u'mwszkS',
#   u'hc': 1308262393,
#   u'hh': u'j.mp',
#   u'l': u'bitly',
#   u'll': [40.218102, -111.613297],
#   u'nk': 0,
#   u'r': u'http://www.AwareMap.com/',
#   u't': 1331923249,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.monroecounty.gov/etc/911/rss.php'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Washington',
#   u'g': u'xxr3Qb',
#   u'gr': u'DC',
#   u'h': u'xxr3Qb',
#   u'hc': 1331919941,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [38.9007, -77.043098],
#   u'nk': 1,
#   u'r': u'http://t.co/03elZC4Q',
#   u't': 1331923250,
#   u'tz': u'America/New_York',
#   u'u': u'http://boxer.senate.gov/en/press/releases/031612.cfm'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.52.7 (KHTML, like Gecko) Version/5.1.2 Safari/534.52.7',
#   u'al': u'pt-br',
#   u'c': u'BR',
#   u'cy': u'Braz',
#   u'g': u'zCaLwp',
#   u'gr': u'27',
#   u'h': u'zUtuOu',
#   u'hc': 1331923068,
#   u'hh': u'1.usa.gov',
#   u'l': u'alelex88',
#   u'll': [-23.549999, -46.616699],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923249,
#   u'tz': u'America/Sao_Paulo',
#   u'u': u'http://apod.nasa.gov/apod/ap120312.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Shrewsbury',
#   u'g': u'9b6kNl',
#   u'gr': u'MA',
#   u'h': u'9b6kNl',
#   u'hc': 1273672411,
#   u'hh': u'bit.ly',
#   u'l': u'bitly',
#   u'll': [42.286499, -71.714699],
#   u'nk': 0,
#   u'r': u'http://www.shrewsbury-ma.gov/selco/',
#   u't': 1331923251,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.shrewsbury-ma.gov/egov/gallery/134127368672998.png'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Shrewsbury',
#   u'g': u'axNK8c',
#   u'gr': u'MA',
#   u'h': u'axNK8c',
#   u'hc': 1273672506,
#   u'hh': u'bit.ly',
#   u'l': u'bitly',
#   u'll': [42.286499, -71.714699],
#   u'nk': 0,
#   u'r': u'http://www.shrewsbury-ma.gov/selco/',
#   u't': 1331923252,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.shrewsbury-ma.gov/egov/gallery/134127368675393.png'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'pl-PL,pl;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'PL',
#   u'cy': u'Luban',
#   u'g': u'wcndER',
#   u'gr': u'77',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [51.116699, 15.2833],
#   u'nk': 0,
#   u'r': u'http://plus.url.google.com/url?sa=z&n=1331923253510&url=http%3A%2F%2F1.usa.gov%2FzkpJBR&usg=TF5iGSqK1_GSADtHqTqjuUZyMIY.',
#   u't': 1331923255,
#   u'tz': u'Europe/Warsaw',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/20100101 Firefox/4.0.1',
#   u'al': u'bg,en-us;q=0.7,en;q=0.3',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923255,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Opera/9.80 (X11; Linux zbov; U; en) Presto/2.10.254 Version/12.00',
#   u'al': u'en-US, en',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=fAQG5ntSGAQHqKPlWzuJKUA9LYeckHZCUxvjQipJDd7Rmmw',
#   u't': 1331923254,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'pt-BR,pt;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': None,
#   u'g': u'zCaLwp',
#   u'h': u'zUtuOu',
#   u'hc': 1331923068,
#   u'hh': u'1.usa.gov',
#   u'l': u'alelex88',
#   u'nk': 0,
#   u'r': u'http://t.co/o1Pd0WeV',
#   u't': 1331923255,
#   u'tz': u'',
#   u'u': u'http://apod.nasa.gov/apod/ap120312.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Seattle',
#   u'g': u'vNJS4H',
#   u'gr': u'WA',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [47.5951, -122.332603],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923258,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4; en-US; rv:1.9.2.27) Gecko/20120216 Firefox/3.6.27',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Washington',
#   u'g': u'wG7OIH',
#   u'gr': u'DC',
#   u'h': u'A0nRz4',
#   u'hc': 1331815838,
#   u'hh': u'1.usa.gov',
#   u'l': u'darrellissa',
#   u'll': [38.937599, -77.092796],
#   u'nk': 0,
#   u'r': u'http://t.co/ND7SoPyo',
#   u't': 1331923259,
#   u'tz': u'America/New_York',
#   u'u': u'http://oversight.house.gov/wp-content/uploads/2012/03/2012-3-15-FOIA-Management-Scorecard.pdf'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Alexandria',
#   u'g': u'vNJS4H',
#   u'gr': u'VA',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [38.790901, -77.094704],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923259,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'_heartbeat_': 1331923261},
#  {u'a': u'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.17) Gecko/20110420 Firefox/3.6.17',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Marietta',
#   u'g': u'2rOUYc',
#   u'gr': u'GA',
#   u'h': u'2rOUYc',
#   u'hc': 1255769846,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [33.953201, -84.5177],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923262,
#   u'tz': u'America/New_York',
#   u'u': u'http://toxtown.nlm.nih.gov/index.php'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'HK',
#   u'cy': u'Central District',
#   u'g': u'nQvgJp',
#   u'gr': u'00',
#   u'h': u'rtrrth',
#   u'hc': 1317318030,
#   u'hh': u'j.mp',
#   u'l': u'walkeryuen',
#   u'll': [22.2833, 114.150002],
#   u'nk': 1,
#   u'r': u'http://forum2.hkgolden.com/view.aspx?type=BW&message=3602284',
#   u't': 1331923263,
#   u'tz': u'Asia/Hong_Kong',
#   u'u': u'http://www.ssd.noaa.gov/PS/TROP/TCFP/data/current/mtloopfpr17.png'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'HK',
#   u'cy': u'Central District',
#   u'g': u'XdUNr',
#   u'gr': u'00',
#   u'h': u'qWkgbq',
#   u'hc': 1317318039,
#   u'hh': u'j.mp',
#   u'l': u'walkeryuen',
#   u'll': [22.2833, 114.150002],
#   u'nk': 1,
#   u'r': u'http://forum2.hkgolden.com/view.aspx?type=BW&message=3602284',
#   u't': 1331923263,
#   u'tz': u'Asia/Hong_Kong',
#   u'u': u'http://www.usno.navy.mil/NOOC/nmfc-ph/RSS/jtwc/ab/abpwsair.jpg'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.5; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Buckfield',
#   u'g': u'zH1BFf',
#   u'gr': u'ME',
#   u'h': u'x3jOIv',
#   u'hc': 1331839576,
#   u'hh': u'1.usa.gov',
#   u'l': u'andyzieminski',
#   u'll': [44.299702, -70.369797],
#   u'nk': 0,
#   u'r': u'http://t.co/6Cx4ROLs',
#   u't': 1331923264,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.usda.gov/wps/portal/usda/usdahome?contentidonly=true&contentid=KYF_Compass_Careers_in_Agriculture.html'},
#  {u'a': u'GoogleMaps/RochesterNY',
#   u'c': u'US',
#   u'cy': u'Provo',
#   u'g': u'mwszkS',
#   u'gr': u'UT',
#   u'h': u'mwszkS',
#   u'hc': 1308262393,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [40.218102, -111.613297],
#   u'nk': 0,
#   u'r': u'http://www.AwareMap.com/',
#   u't': 1331923262,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.monroecounty.gov/etc/911/rss.php'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'IT',
#   u'cy': u'Venice',
#   u'g': u'wcndER',
#   u'gr': u'20',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [45.438599, 12.3267],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923264,
#   u'tz': u'Europe/Rome',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
#   u'al': u'es-ES',
#   u'c': u'ES',
#   u'cy': u'Alcal',
#   u'g': u'zQ95Hi',
#   u'gr': u'51',
#   u'h': u'ytZYWR',
#   u'hc': 1331670549,
#   u'hh': u'bitly.com',
#   u'l': u'jplnews',
#   u'll': [37.516701, -5.9833],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923265,
#   u'tz': u'Africa/Ceuta',
#   u'u': u'http://voyager.jpl.nasa.gov/imagesvideo/uranus.html'},
#  {u'a': u'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.6; en-US; rv:1.9.2.19) Gecko/20110707 Firefox/3.6.19',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Davidsonville',
#   u'g': u'wcndER',
#   u'gr': u'MD',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [38.939201, -76.635002],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923267,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; GTB7.3; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.30729; .NET4.0C; InfoPath.2; .NET CLR 1.1.4322; .NET CLR 3.5.30729)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Hockessin',
#   u'g': u'y3ZImz',
#   u'gr': u'DE',
#   u'h': u'y3ZImz',
#   u'hc': 1331064158,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [39.785, -75.682297],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923267,
#   u'tz': u'America/New_York',
#   u'u': u'http://portal.hud.gov/hudportal/documents/huddoc?id=12-04ml.pdf'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/534.53.11 (KHTML, like Gecko) Version/5.1.3 Safari/534.53.10',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Lititz',
#   u'g': u'wWiOiD',
#   u'gr': u'PA',
#   u'h': u'wWiOiD',
#   u'hc': 1330217829,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [40.174999, -76.3078],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FwWiOiD&h=MAQERI5fLAQFvFg3Jhes38U64waF7QclFtZlHG4yEVpkTSA',
#   u't': 1331923267,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.tricare.mil/mybenefit/ProfileFilter.do;jsessionid=PJDJhXzQbWLQ5GLygF5zrfhMfxZlYndrdYh5Zvm9tlYMXDZW41QY!-541484568?puri=/home/Dental/DentalProgram'},
#  {u'a': u'Mozilla/5.0 (Windows; U; Windows NT 5.1; es-ES; rv:1.9.1.1) Gecko/20090715 Firefox/3.5.1 ( .NET CLR 3.5.30729)',
#   u'al': u'es-es,es;q=0.8,en-us;q=0.5,en;q=0.3',
#   u'c': u'ES',
#   u'cy': u'Bilbao',
#   u'g': u'wcndER',
#   u'gr': u'59',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [43.25, -2.9667],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923268,
#   u'tz': u'Europe/Madrid',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-GB,en;q=0.8,en-US;q=0.6,en-AU;q=0.4',
#   u'c': u'MY',
#   u'cy': u'Kuala Lumpur',
#   u'g': u'wcndER',
#   u'gr': u'14',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [3.1667, 101.699997],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923269,
#   u'tz': u'Asia/Kuala_Lumpur',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'ro-RO,ro;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'CY',
#   u'cy': u'Nicosia',
#   u'g': u'wcndER',
#   u'gr': u'04',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [35.166698, 33.366699],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/?ref=tn_tnmn',
#   u't': 1331923268,
#   u'tz': u'Asia/Nicosia',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'BR',
#   u'cy': u'SPaulo',
#   u'g': u'zCaLwp',
#   u'gr': u'27',
#   u'h': u'zUtuOu',
#   u'hc': 1331923068,
#   u'hh': u'1.usa.gov',
#   u'l': u'alelex88',
#   u'll': [-23.5333, -46.616699],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923269,
#   u'tz': u'America/Sao_Paulo',
#   u'u': u'http://apod.nasa.gov/apod/ap120312.html'},
#  {u'a': u'Mozilla/5.0 (iPad; CPU OS 5_0_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Version/5.1 Mobile/9A405 Safari/7534.48.3',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'vNJS4H',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923270,
#   u'tz': u'',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B367 Safari/531.21.10',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'FPX0IM',
#   u'h': u'FPX0IL',
#   u'hc': 1331922978,
#   u'hh': u'1.usa.gov',
#   u'l': u'twittershare',
#   u'nk': 1,
#   u'r': u'http://t.co/5xlp0B34',
#   u't': 1331923270,
#   u'tz': u'',
#   u'u': u'http://www.ed.gov/news/media-advisories/us-department-education-and-advance-illinois-discuss-transforming-teaching-pro'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-GB,en-US;q=0.8,en;q=0.6',
#   u'c': u'GB',
#   u'cy': u'Huddersfield',
#   u'g': u'wcndER',
#   u'gr': u'G8',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [53.650002, -1.7833],
#   u'nk': 0,
#   u'r': u'http://plus.url.google.com/url?sa=z&n=1331923308907&url=http%3A%2F%2F1.usa.gov%2FzkpJBR&usg=aqYZtNlwKGwBPD7VQg2AGSQUmIE.',
#   u't': 1331923271,
#   u'tz': u'Europe/London',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Fairport',
#   u'g': u'wcndER',
#   u'gr': u'NY',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [43.100498, -77.426003],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=UAQF87rDtAQGLJahNrJKHLoFfS5vZXgdXxw9CigHifduvZA',
#   u't': 1331923271,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.2; .NET4.0C; .NET4.0E)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Honolulu',
#   u'g': u'FO8qn8',
#   u'gr': u'HI',
#   u'h': u'zGDswc',
#   u'hc': 1331922709,
#   u'hh': u'bit.ly',
#   u'kw': u'SBXreturns',
#   u'l': u'kcatian',
#   u'll': [21.3139, -157.824493],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923276,
#   u'tz': u'Pacific/Honolulu',
#   u'u': u'http://www.cnic.navy.mil/navycni/groups/public/@hawaii/documents/document/cnicp_a286591.pdf'},
#  {u'a': u'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4; en-US; rv:1.9.0.19) Gecko/2010031218 Firefox/3.0.19',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Knoxville',
#   u'g': u'y5uuLa',
#   u'gr': u'TN',
#   u'h': u'AfJNSd',
#   u'hc': 1331825200,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [35.972401, -83.959503],
#   u'nk': 1,
#   u'r': u'http://t.co/1ghGl5Pl',
#   u't': 1331923275,
#   u'tz': u'America/Chicago',
#   u'u': u'http://www.nasa.gov/topics/earth/features/2012-snow.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 1,
#   u'r': u'http://plus.url.google.com/url?sa=z&n=1331923275708&url=http%3A%2F%2F1.usa.gov%2FzkpJBR&usg=lUoN-YVtghjS57X6UrYNqro4HSI.',
#   u't': 1331923276,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': None,
#   u'g': u'xOsMcy',
#   u'h': u'yV8hww',
#   u'hc': 1331829147,
#   u'hh': u'1.usa.gov',
#   u'l': u'wwpinc',
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FyV8hww&h=GAQHUfoFWAQGsnXEom3HohpAApWT6OOQy08mVRAaaolHDlA',
#   u't': 1331923277,
#   u'tz': u'',
#   u'u': u'http://www.army.mil/article/75464/Marksmanship_Unit_adding_wounded_warrior_sections/'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.2; .NET4.0C; .NET4.0E)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Honolulu',
#   u'g': u'FO8qn8',
#   u'gr': u'HI',
#   u'h': u'zGDswc',
#   u'hc': 1331922709,
#   u'hh': u'1.usa.gov',
#   u'kw': u'SBXreturns',
#   u'l': u'kcatian',
#   u'll': [21.3139, -157.824493],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923278,
#   u'tz': u'Pacific/Honolulu',
#   u'u': u'http://www.cnic.navy.mil/navycni/groups/public/@hawaii/documents/document/cnicp_a286591.pdf'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': None,
#   u'g': u'vNJS4H',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923278,
#   u'tz': u'',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; SU 3.96; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Washington',
#   u'g': u'wmAjaQ',
#   u'gr': u'DC',
#   u'h': u'z6glLT',
#   u'hc': 1331665443,
#   u'hh': u'1.usa.gov',
#   u'l': u'citizencorps',
#   u'll': [38.897099, -77.040901],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923279,
#   u'tz': u'America/New_York',
#   u'u': u'http://citizencorps.gov/getstarted/youth/youthindex.shtm'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Stamford',
#   u'g': u'vNJS4H',
#   u'gr': u'CT',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [41.097801, -73.518799],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923279,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B179',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Bronx',
#   u'g': u'BNDz',
#   u'gr': u'NY',
#   u'h': u'14Q1q3',
#   u'hc': 1246975140,
#   u'hh': u'1.usa.gov',
#   u'l': u'tweetdeckapi',
#   u'll': [40.849899, -73.8769],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923279,
#   u'tz': u'America/New_York',
#   u'u': u'http://radar.weather.gov/Conus/northeast_loop.php'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Saint Louis',
#   u'g': u'wWiOiD',
#   u'gr': u'MO',
#   u'h': u'wWiOiD',
#   u'hc': 1330217829,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [38.6143, -90.444397],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FwWiOiD&h=pAQFg1hNvAQHAGtvH4GVtNG_4z5VmkNesOvnGD9t126HN8w&enc=AZOxntKo6VqhJI5pIgviFZiD9z6bpk0XQDQ92Mboc1XBhKs_wA9h-nm2KF7249rX6Yh_ikqXfFo032KIHym15NC5Hm-RUFV-t3VSOhO-lk7oww',
#   u't': 1331923281,
#   u'tz': u'America/Chicago',
#   u'u': u'http://www.tricare.mil/mybenefit/ProfileFilter.do;jsessionid=PJDJhXzQbWLQ5GLygF5zrfhMfxZlYndrdYh5Zvm9tlYMXDZW41QY!-541484568?puri=/home/Dental/DentalProgram'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'IT',
#   u'cy': u'Rome',
#   u'g': u'wcndER',
#   u'gr': u'07',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [41.900002, 12.4833],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=SAQGcXJwXAQH8Dl_HB2zWjRG-1qeuKDE37uV7TTvk129TKA',
#   u't': 1331923280,
#   u'tz': u'Europe/Rome',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; rv:9.0.1) Gecko/20100101 Firefox/9.0.1',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Dudley',
#   u'g': u'vNJS4H',
#   u'gr': u'MA',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [42.059399, -71.9356],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923281,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_0_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9A406 Twitter for iPhone',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Bowie',
#   u'g': u'16aNQi',
#   u'gr': u'MD',
#   u'h': u'xoB0ID',
#   u'hc': 1328745636,
#   u'hh': u'1.usa.gov',
#   u'l': u'usagovteam',
#   u'll': [38.9576, -76.756599],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923281,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.irs.gov/individuals/article/0,,id=96196,00.html'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Los Angeles',
#   u'g': u'vNJS4H',
#   u'gr': u'CA',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [34.065701, -118.436203],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923284,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'BlackBerry8520/5.0.0.592 Profile/MIDP-2.1 Configuration/CLDC-1.1 VendorID/168',
#   u'al': u'en',
#   u'c': None,
#   u'g': u'yD1K8w',
#   u'h': u'AAEmdT',
#   u'hc': 1331756442,
#   u'hh': u'1.usa.gov',
#   u'l': u'healthit',
#   u'nk': 0,
#   u'r': u'http://mobile.twitter.com/AIDSgov',
#   u't': 1331923284,
#   u'tz': u'',
#   u'u': u'http://www.hhs.gov/live/?utm_source=ketchum&utm_medium=pitchemail&utm_campaign=mobileroundtable_hhs_livestreaming_3_14_2012%2B'},
#  {u'a': u'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.28) Gecko/20120306 Firefox/3.6.28',
#   u'al': u'en-us,en;q=0.5',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/home.php?',
#   u't': 1331923286,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:9.0.1) Gecko/20100101 Firefox/9.0.1',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Savannah',
#   u'g': u'vNJS4H',
#   u'gr': u'GA',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [31.997101, -80.9645],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923284,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2; .NET4.0C; MS-RTC LM 8)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Washington',
#   u'g': u'znwhw1',
#   u'gr': u'DC',
#   u'h': u'xurm7e',
#   u'hc': 1331853485,
#   u'hh': u'1.usa.gov',
#   u'l': u'aashtojournal',
#   u'll': [38.909698, -77.023102],
#   u'nk': 0,
#   u'r': u'http://www.aashtojournal.org/Pages/031612senate.aspx',
#   u't': 1331923285,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=112&session=2&vote=00048'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-gb,en;q=0.5',
#   u'c': u'MT',
#   u'cy': u'Sliema',
#   u'g': u'wcndER',
#   u'gr': u'00',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [35.912498, 14.5019],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=0AQGf_X9OAQFoS-3nfrl3To6BNnsCtzK0HL1O98ZfkXKzsQ',
#   u't': 1331923288,
#   u'tz': u'Europe/Malta',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P925/V10e Build/FRG83G) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Woodbridge',
#   u'g': u'wcndER',
#   u'gr': u'VA',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [38.625702, -77.266502],
#   u'nk': 0,
#   u'r': u'http://m.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=5AQGaIchD&enc=AZNFqXj6jEJucL_ibqRU1RrHoswuu_1lvTqb961sibFZMt75vb-2Uf2tHkyKhDkP5vBK2fDhx7ns4OA5XFS0dUelVgyqB6quUWg-j0OZ-f37XQ72Oh-sCmmywrUxXugQ9JH8jWivDxVWywHKLNnqKGWN2VRKPimytTvIs-VRnEm9PE3QknYsOxm6AQ5CcQdxDvs',
#   u't': 1331923288,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Grand Rapids',
#   u'g': u'FO8od2',
#   u'gr': u'MI',
#   u'h': u'FO8od1',
#   u'hc': 1331921833,
#   u'hh': u'ds.io',
#   u'l': u'developmentseed',
#   u'll': [42.977699, -85.710999],
#   u'nk': 1,
#   u'r': u'http://t.co/wgctD0rd',
#   u't': 1331923287,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.nature.nps.gov/features/eclipse/wheretoview.cfm'},
#  {u'a': u'Mozilla/5.0 (compatible; MSIE 9.0; Windows Phone OS 7.5; Trident/5.0; IEMobile/9.0; SAMSUNG; GT-I8350)',
#   u'al': u'en-IN',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923287,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS127482)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Chula Vista',
#   u'g': u'FOogtm',
#   u'gr': u'CA',
#   u'h': u'AkgL2C',
#   u'hc': 1331920879,
#   u'hh': u'1.usa.gov',
#   u'l': u'twitterfeed',
#   u'll': [32.636101, -117.0532],
#   u'nk': 1,
#   u'r': u'http://t.co/ovz0wT2O',
#   u't': 1331923291,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.whitehouse.gov/the-press-office/2012/03/16/statement-president-retirement-congressman-gary-ackerman?utm_source=twitterfeed&utm_medium=twitter'},
#  {u'_heartbeat_': 1331923291},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'pt-BR,pt;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'BR',
#   u'cy': u'Curitiba',
#   u'g': u'zCaLwp',
#   u'gr': u'18',
#   u'h': u'zUtuOu',
#   u'hc': 1331923068,
#   u'hh': u'1.usa.gov',
#   u'l': u'alelex88',
#   u'll': [-25.4167, -49.25],
#   u'nk': 0,
#   u'r': u'http://t.co/o1Pd0WeV',
#   u't': 1331923292,
#   u'tz': u'America/Sao_Paulo',
#   u'u': u'http://apod.nasa.gov/apod/ap120312.html'},
#  {u'a': u'Mozilla/5.0 (iPhone; U; CPU iPhone OS 5_0_1 like Mac OS X; en_US) AppleWebKit (KHTML, like Gecko) Mobile [FBAN/FBForIPhone;FBAV/4.1;FBBV/4100.0;FBDV/iPhone3,1;FBMD/iPhone;FBSN/iPhone OS;FBSV/5.0.1;FBSS/2; FBCR/Carrier;FBID/phone;FBLC/en_US;FBSF/2.0]',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://m.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=vAQGtNTof',
#   u't': 1331923293,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B176',
#   u'al': u'en-us',
#   u'c': u'HK',
#   u'cy': u'Central District',
#   u'g': u'XdUNr',
#   u'gr': u'00',
#   u'h': u'qWkgbq',
#   u'hc': 1317318039,
#   u'hh': u'j.mp',
#   u'l': u'walkeryuen',
#   u'll': [22.2833, 114.150002],
#   u'nk': 0,
#   u'r': u'http://lalaf.com/ihkg/app/iphone.4_71.php?gif=no&font=14&ver=4.73&na=1&&img=yes&smy=yes&forum=7&id=3602284&page=1&allpage=9&loc=129&bloc',
#   u't': 1331923292,
#   u'tz': u'Asia/Hong_Kong',
#   u'u': u'http://www.usno.navy.mil/NOOC/nmfc-ph/RSS/jtwc/ab/abpwsair.jpg'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B176',
#   u'al': u'en-us',
#   u'c': u'HK',
#   u'cy': u'Central District',
#   u'g': u'nQvgJp',
#   u'gr': u'00',
#   u'h': u'rtrrth',
#   u'hc': 1317318030,
#   u'hh': u'j.mp',
#   u'l': u'walkeryuen',
#   u'll': [22.2833, 114.150002],
#   u'nk': 0,
#   u'r': u'http://lalaf.com/ihkg/app/iphone.4_71.php?gif=no&font=14&ver=4.73&na=1&&img=yes&smy=yes&forum=7&id=3602284&page=1&allpage=9&loc=129&bloc',
#   u't': 1331923292,
#   u'tz': u'Asia/Hong_Kong',
#   u'u': u'http://www.ssd.noaa.gov/PS/TROP/TCFP/data/current/mtloopfpr17.png'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.2; .NET4.0C; .NET4.0E)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Honolulu',
#   u'g': u'FO8qn8',
#   u'gr': u'HI',
#   u'h': u'zGDswc',
#   u'hc': 1331922709,
#   u'hh': u'1.usa.gov',
#   u'kw': u'SBXreturns',
#   u'l': u'kcatian',
#   u'll': [21.3139, -157.824493],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923294,
#   u'tz': u'Pacific/Honolulu',
#   u'u': u'http://www.cnic.navy.mil/navycni/groups/public/@hawaii/documents/document/cnicp_a286591.pdf'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.2; .NET4.0C; .NET4.0E)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Honolulu',
#   u'g': u'FO8qn8',
#   u'gr': u'HI',
#   u'h': u'zGDswc',
#   u'hc': 1331922709,
#   u'hh': u'1.usa.gov',
#   u'kw': u'SBXreturns',
#   u'l': u'kcatian',
#   u'll': [21.3139, -157.824493],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923295,
#   u'tz': u'Pacific/Honolulu',
#   u'u': u'http://www.cnic.navy.mil/navycni/groups/public/@hawaii/documents/document/cnicp_a286591.pdf'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.1; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; InfoPath.2; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; .NET4.0E)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Honolulu',
#   u'g': u'x98anS',
#   u'gr': u'HI',
#   u'h': u'FOb6ww',
#   u'hc': 1331921801,
#   u'hh': u'bit.ly',
#   u'kw': u'RealignOPNAVstaff',
#   u'l': u'kcatian',
#   u'll': [21.3139, -157.824493],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923295,
#   u'tz': u'Pacific/Honolulu',
#   u'u': u'http://www.navy.mil/search/display.asp?story_id=65845'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Cambridge',
#   u'g': u'y7wGgq',
#   u'gr': u'MA',
#   u'h': u'zwlxab',
#   u'hc': 1331908890,
#   u'hh': u'1.usa.gov',
#   u'l': u'americanactionnetwork',
#   u'll': [42.3741, -71.107201],
#   u'nk': 0,
#   u'r': u'http://t.co/ihUhQF1r',
#   u't': 1331923296,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.cbo.gov/publication/43083'},
#  {u'a': u'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
#   u'al': u'en-GB',
#   u'c': u'GB',
#   u'cy': u'Birmingham',
#   u'g': u'FOlpyK',
#   u'gr': u'A7',
#   u'h': u'yK8zBm',
#   u'hc': 1331921292,
#   u'hh': u'1.usa.gov',
#   u'l': u'twitterfeed',
#   u'll': [52.466702, -1.9167],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923297,
#   u'tz': u'Europe/London',
#   u'u': u'http://www.nasa.gov/mission_pages/station/multimedia/gallery/jsc2012e034742.html?utm_medium=facebook&utm_source=twitterfeed'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
#   u'al': u'en',
#   u'c': u'US',
#   u'cy': u'Paramus',
#   u'g': u'e5SvKE',
#   u'gr': u'NJ',
#   u'h': u'fqPSr9',
#   u'hc': 1301298479,
#   u'hh': u'1.usa.gov',
#   u'l': u'tweetdeckapi',
#   u'll': [40.9445, -74.07],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923296,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.fda.gov/AdvisoryCommittees/CommitteesMeetingMaterials/Drugs/Anti-InfectiveDrugsAdvisoryCommittee/ucm242307.htm'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.100 Safari/535.19',
#   u'al': u'en-US,en;q=0.8',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923297,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'pt-PT,pt;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'PT',
#   u'cy': u'Lisboa',
#   u'g': u'xVZg4P',
#   u'gr': u'14',
#   u'h': u'wqUkTo',
#   u'hc': 1331908247,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [38.716702, -9.1333],
#   u'nk': 1,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2Fgo.nasa.gov%2FwqUkTo%3Fref%3Dnf&h=lAQHkOnePAQEphexVJoSTOmQ8WpdDlw0jz6N7cQjIB0D3aQ',
#   u't': 1331923298,
#   u'tz': u'Europe/Lisbon',
#   u'u': u'http://www.nasa.gov/multimedia/imagegallery/image_feature_2199.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'fr-FR,fr;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'FR',
#   u'cy': u'Lambersart',
#   u'g': u'wcndER',
#   u'gr': u'B4',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [50.650002, 3.0333],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=iAQHSRJiqAQHWyGKlJLyoapZ3t68gz9Nwoh20N4xWZmgLwg',
#   u't': 1331923298,
#   u'tz': u'Europe/Paris',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; WOW64; Trident/5.0)',
#   u'al': u'en-gb',
#   u'c': u'GB',
#   u'cy': u'Bodmin',
#   u'g': u'wcndER',
#   u'gr': u'C6',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [50.4664, -4.7256],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923300,
#   u'tz': u'Europe/London',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/534.54.16 (KHTML, like Gecko) Version/5.1.4 Safari/534.54.16',
#   u'al': u'en-us',
#   u'c': u'DK',
#   u'cy': u'Herning',
#   u'g': u'wcndER',
#   u'gr': u'18',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [56.133301, 8.9833],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923299,
#   u'tz': u'Europe/Copenhagen',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B176 Twitter for iPhone',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'xRWPdw',
#   u'h': u'xRWPdw',
#   u'hc': 1331824318,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'nk': 0,
#   u'r': u'https://twitter.com/molleymoody/status/180636065898561536',
#   u't': 1331923298,
#   u'tz': u'',
#   u'u': u'http://www.whitehouse.gov/the-press-office/2012/03/15/statement-president-meeting-interagency-task-force-monitor-and-combat-tr'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11 CoolNovo/2.0.1.40',
#   u'al': u'it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'IT',
#   u'cy': u'Piombino',
#   u'g': u'wcndER',
#   u'gr': u'16',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [42.916698, 10.5333],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=AAQGqBXRtAQHmxmkJ5g262XdDwz7I5SRglQGwLhqJJ0yeEg',
#   u't': 1331923301,
#   u'tz': u'Europe/Rome',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Grand Rapids',
#   u'g': u'vNJS4H',
#   u'gr': u'MI',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [42.942501, -85.616096],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923300,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_6) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'White Plains',
#   u'g': u'vNJS4H',
#   u'gr': u'NY',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [41.029099, -73.758003],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923302,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_0_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Version/5.1 Mobile/9A405 Safari/7534.48.3',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'vNJS4H',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923304,
#   u'tz': u'',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B176 Twitter for iPhone',
#   u'al': u'en-gb',
#   u'c': u'GB',
#   u'cy': u'London',
#   u'g': u'b2UtUJ',
#   u'gr': u'H9',
#   u'h': u'ieCdgH',
#   u'hc': 1301393171,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [51.500198, -0.1262],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923304,
#   u'tz': u'Europe/London',
#   u'u': u'http://apod.nasa.gov/apod/'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#   u'al': u'it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'IT',
#   u'cy': u'Rome',
#   u'g': u'wcndER',
#   u'gr': u'07',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [41.900002, 12.4833],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/',
#   u't': 1331923303,
#   u'tz': u'Europe/Rome',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Columbus',
#   u'g': u'xVTtSE',
#   u'gr': u'OH',
#   u'h': u'yeE6VR',
#   u'hc': 1331905829,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [40.028999, -83.080902],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2Fgo.nasa.gov%2FyeE6VR&h=6AQEiklj9AQG13VGN8spje1xochjK_jrdTcyKW6ksx4U5LQ',
#   u't': 1331923304,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.nasa.gov/connect/social/index.html'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Mesquite',
#   u'g': u'wcndER',
#   u'gr': u'TX',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [32.7673, -96.624702],
#   u'nk': 1,
#   u'r': u'http://t.co/J6qInqf7',
#   u't': 1331923304,
#   u'tz': u'America/Chicago',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; CPNTDF)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Farmington',
#   u'g': u'wDITWn',
#   u'gr': u'CT',
#   u'h': u'xoC874',
#   u'hc': 1331893247,
#   u'hh': u'1.usa.gov',
#   u'l': u'bufferapp',
#   u'll': [41.725201, -72.829498],
#   u'nk': 0,
#   u'r': u'http://stocktwits.com/kevindepew',
#   u't': 1331923305,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.federalreserve.gov/newsevents/lectures/about.htm'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; GTB7.3; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C)',
#   u'al': u'en-US',
#   u'c': u'FR',
#   u'cy': u'Limeil-brnnes',
#   u'g': u'wcndER',
#   u'gr': u'A8',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [48.733299, 2.4833],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=-AQHCKkYsAQFMfW3xTmwoI6utyXwNrbHZ4EPubKNws2GzKA',
#   u't': 1331923305,
#   u'tz': u'Europe/Paris',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'GoogleMaps/RochesterNY',
#   u'c': u'US',
#   u'cy': u'Provo',
#   u'g': u'mwszkS',
#   u'gr': u'UT',
#   u'h': u'mwszkS',
#   u'hc': 1308262393,
#   u'hh': u'j.mp',
#   u'l': u'bitly',
#   u'll': [40.218102, -111.613297],
#   u'nk': 0,
#   u'r': u'http://www.AwareMap.com/',
#   u't': 1331923307,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.monroecounty.gov/etc/911/rss.php'},
#  {u'a': u'Mozilla/5.0 (iPhone; U; CPU iPhone OS 5_1 like Mac OS X; en_US) AppleWebKit (KHTML, like Gecko) Mobile [FBAN/FBForIPhone;FBAV/4.1;FBBV/4100.0;FBDV/iPhone4,1;FBMD/iPhone;FBSN/iPhone OS;FBSV/5.1;FBSS/2; FBCR/AT&T;FBID/phone;FBLC/en_US;FBSF/2.0]',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'wFto9d',
#   u'h': u'yIkLDb',
#   u'hc': 1331328857,
#   u'hh': u'1.usa.gov',
#   u'l': u'healthfinderfacebook',
#   u'nk': 1,
#   u'r': u'http://m.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FyIkLDb&h=kAQGOHjmv',
#   u't': 1331923308,
#   u'tz': u'',
#   u'u': u'http://healthfinder.gov/prevention/ViewTopic.aspx?topicId=89'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=wAQFfZPOVAQEQUqVZ2vbRKegGP36FGhQ6xWc0DgcOR-R2og',
#   u't': 1331923309,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; yie9)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'San Francisco',
#   u'g': u'vJD54',
#   u'gr': u'CA',
#   u'h': u'hgAh61',
#   u'hc': 1303843769,
#   u'hh': u'1.usa.gov',
#   u'l': u'bettyruth',
#   u'll': [37.7645, -122.429398],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923309,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.energy.ca.gov/HERS/index.html'},
#  {u'a': u'NokiaC3-00/5.0 (08.65) Profile/MIDP-2.1 Configuration/CLDC-1.1 Mozilla/5.0 AppleWebKit/420+ (KHTML, like Gecko) Safari/420+',
#   u'al': u'es-US',
#   u'c': u'MX',
#   u'cy': u'Durango',
#   u'g': u'xVZg4P',
#   u'gr': u'10',
#   u'h': u'wqUkTo',
#   u'hc': 1331908247,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [24.0333, -104.666702],
#   u'nk': 0,
#   u'r': u'http://t.co/lY3ZPJaN',
#   u't': 1331923313,
#   u'tz': u'America/Mazatlan',
#   u'u': u'http://www.nasa.gov/multimedia/imagegallery/image_feature_2199.html'},
#  {u'a': u'Mozilla/5.0 (iPhone; U; CPU iPhone OS 5_1 like Mac OS X; en_US) AppleWebKit (KHTML, like Gecko) Mobile [FBAN/FBForIPhone;FBAV/4.1;FBBV/4100.0;FBDV/iPhone4,1;FBMD/iPhone;FBSN/iPhone OS;FBSV/5.1;FBSS/2; FBCR/Verizon;FBID/phone;FBLC/en_US;FBSF/2.0]',
#   u'al': u'en-us',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://m.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=8AQGIBzly',
#   u't': 1331923314,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'IE',
#   u'cy': u'Dublin',
#   u'g': u'wcndER',
#   u'gr': u'07',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [53.333099, -6.2489],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=YAQFbqv-wAQEYbLhVB7n9RPiZnxtxtAWrav9uZ2pYYA4uOQ',
#   u't': 1331923315,
#   u'tz': u'Europe/Dublin',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Kennesaw',
#   u'g': u'2rOUYc',
#   u'gr': u'GA',
#   u'h': u'2rOUYc',
#   u'hc': 1255769846,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [34.010399, -84.623901],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331923317,
#   u'tz': u'America/New_York',
#   u'u': u'http://toxtown.nlm.nih.gov/index.php'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#   u'al': u'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'HK',
#   u'cy': u'A Po Long',
#   u'g': u'XdUNr',
#   u'gr': u'00',
#   u'h': u'qWkgbq',
#   u'hc': 1317318039,
#   u'hh': u'j.mp',
#   u'l': u'walkeryuen',
#   u'll': [22.2833, 114.0],
#   u'nk': 1,
#   u'r': u'http://forum2.hkgolden.com/view.aspx?type=BW&message=3602284',
#   u't': 1331923317,
#   u'tz': u'Asia/Hong_Kong',
#   u'u': u'http://www.usno.navy.mil/NOOC/nmfc-ph/RSS/jtwc/ab/abpwsair.jpg'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#   u'al': u'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'HK',
#   u'cy': u'A Po Long',
#   u'g': u'nQvgJp',
#   u'gr': u'00',
#   u'h': u'rtrrth',
#   u'hc': 1317318030,
#   u'hh': u'j.mp',
#   u'l': u'walkeryuen',
#   u'll': [22.2833, 114.0],
#   u'nk': 1,
#   u'r': u'http://forum2.hkgolden.com/view.aspx?type=BW&message=3602284',
#   u't': 1331923317,
#   u'tz': u'Asia/Hong_Kong',
#   u'u': u'http://www.ssd.noaa.gov/PS/TROP/TCFP/data/current/mtloopfpr17.png'},
#  {u'_heartbeat_': 1331923321},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_6) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'White Plains',
#   u'g': u'vNJS4H',
#   u'gr': u'NY',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [41.029099, -73.758003],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331923322,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': None,
# ...
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Topeka',
#   u'g': u'yOqnT2',
#   u'gr': u'KS',
#   u'h': u'wmVLeM',
#   u'hc': 1331587460,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_1np55qnriq',
#   u'll': [39.039902, -95.717003],
#   u'nk': 1,
#   u'r': u'http://t.co/xyxb3zNp',
#   u't': 1331926812,
#   u'tz': u'America/Chicago',
#   u'u': u'https://ag.ks.gov/media-center/news-releases/2012/03/12/schmidt-final-agreements-filed-in-mortgage-settlement'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Denver',
#   u'g': u'vNJS4H',
#   u'gr': u'CO',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [39.743698, -104.979301],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926813,
#   u'tz': u'America/Denver',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Stamford',
#   u'g': u'vNJS4H',
#   u'gr': u'CT',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [41.097801, -73.518799],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926814,
#   u'tz': u'America/New_York',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'San Francisco',
#   u'g': u'xVZg4P',
#   u'gr': u'CA',
#   u'h': u'wqUkTo',
#   u'hc': 1331908247,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [37.7645, -122.429398],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2Fgo.nasa.gov%2FwqUkTo%3Fref%3Dnf&h=oAQH23P2yAQHdrJUWyL-qzucCKvU-9HEFRiza5a74r2bYhA',
#   u't': 1331926815,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.nasa.gov/multimedia/imagegallery/image_feature_2199.html'},
#  {u'a': u'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_3; en-us) AppleWebKit/533.16 (KHTML, like Gecko) Version/5.0 Safari/533.16',
#   u'al': u'en-US',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331926816,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Washington',
#   u'g': u'Au3aUS',
#   u'gr': u'DC',
#   u'h': u'A9ct6C',
#   u'hc': 1331926420,
#   u'hh': u'1.usa.gov',
#   u'l': u'ncsha',
#   u'll': [38.904202, -77.031998],
#   u'nk': 1,
#   u'r': u'http://www.ncsha.org/',
#   u't': 1331926817,
#   u'tz': u'America/New_York',
#   u'u': u'http://portal.hud.gov/hudportal/HUD?src=/press/press_releases_media_advisories/2012/HUDNo.12-055'},
#  {u'a': u'Mozilla/5.0 (iPad; CPU OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B176 Twitter for iPad',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Jacksonville',
#   u'g': u'b2UtUJ',
#   u'gr': u'FL',
#   u'h': u'ieCdgH',
#   u'hc': 1301393171,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'll': [30.279301, -81.585098],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926818,
#   u'tz': u'America/New_York',
#   u'u': u'http://apod.nasa.gov/apod/'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.52.7 (KHTML, like Gecko) Version/5.1.2 Safari/534.52.7',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Frisco',
#   u'g': u'vNJS4H',
#   u'gr': u'TX',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [33.149899, -96.855499],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926820,
#   u'tz': u'America/Chicago',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Houston',
#   u'g': u'zIgLx8',
#   u'gr': u'TX',
#   u'h': u'yrPaLt',
#   u'hc': 1331903484,
#   u'hh': u'aash.to',
#   u'l': u'aashto',
#   u'll': [29.775499, -95.415199],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926823,
#   u'tz': u'America/Chicago',
#   u'u': u'http://ntl.bts.gov/lib/44000/44300/44374/FHWA-JP0-11-154_Clarus_Overview_final.pdf'},
#  {u'a': u'Mozilla/5.0 (BlackBerry; U; BlackBerry 9800; en-US) AppleWebKit/534.1+ (KHTML, like Gecko) Version/6.0.0.246 Mobile Safari/534.1+',
#   u'al': u'en-US,en;q=0.5',
#   u'c': None,
#   u'g': u'xIcyim',
#   u'h': u'yG1TTf',
#   u'hc': 1331728309,
#   u'hh': u'go.nasa.gov',
#   u'l': u'nasatwitter',
#   u'nk': 0,
#   u'r': u'http://t.co/g1VKE8zS',
#   u't': 1331926824,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/hurricanes/archives/2012/h2012_Lua.html'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'es-es,es;q=0.8,en-us;q=0.5,en;q=0.3',
#   u'c': u'HN',
#   u'cy': u'Tegucigalpa',
#   u'g': u'zCaLwp',
#   u'gr': u'08',
#   u'h': u'w63FZW',
#   u'hc': 1331546756,
#   u'hh': u'1.usa.gov',
#   u'l': u'bufferapp',
#   u'll': [14.1, -87.216698],
#   u'nk': 0,
#   u'r': u'http://t.co/A8TJyibE',
#   u't': 1331926825,
#   u'tz': u'America/Tegucigalpa',
#   u'u': u'http://apod.nasa.gov/apod/ap120312.html'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B179',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Los Angeles',
#   u'g': u'qMac9k',
#   u'gr': u'CA',
#   u'h': u'qds1Ge',
#   u'hc': 1310473559,
#   u'hh': u'1.usa.gov',
#   u'l': u'healthypeople',
#   u'll': [34.041599, -118.298798],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331926825,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://healthypeople.gov/2020/connect/webinars.aspx'},
#  {u'a': u'Mozilla/5.0 (compatible; Fedora Core 3) FC3 KDE',
#   u'c': u'US',
#   u'cy': u'Bellevue',
#   u'g': u'zu2M5o',
#   u'gr': u'WA',
#   u'h': u'zDhdro',
#   u'hc': 1331586192,
#   u'hh': u'bit.ly',
#   u'l': u'glimtwin',
#   u'll': [47.615398, -122.210297],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331926827,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.federalreserve.gov/newsevents/press/bcreg/bcreg20120312a1.pdf'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Payson',
#   u'g': u'wcndER',
#   u'gr': u'UT',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'll': [40.014198, -111.738899],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FzkpJBR&h=1AQHS8d62AQETyuStgP94NI9mgq0S__pVUHYllUlDpwII1w',
#   u't': 1331926828,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (X11; U; OpenVMS AlphaServer_ES40; en-US; rv:1.4) Gecko/20030826 SWB/V1.4 (HP)',
#   u'c': u'US',
#   u'cy': u'Bellevue',
#   u'g': u'zu2M5o',
#   u'gr': u'WA',
#   u'h': u'zDhdro',
#   u'hc': 1331586192,
#   u'hh': u'1.usa.gov',
#   u'l': u'glimtwin',
#   u'll': [47.615398, -122.210297],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331926828,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.federalreserve.gov/newsevents/press/bcreg/bcreg20120312a1.pdf'},
#  {u'a': u'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Pittsburg',
#   u'g': u'y3reI1',
#   u'gr': u'CA',
#   u'h': u'y3reI1',
#   u'hc': 1331926120,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [38.0051, -121.838699],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2Fy3reI1&h=nAQFGknZ0AQE_Auz9Y7w0zKCW7ozSrGuhoygtoHLS6Ihq2g',
#   u't': 1331926829,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.sba.gov/community/blogs/community-blogs/business-law-advisor/registering-woman-minority-or-veteran-owned-bus'},
#  {u'_heartbeat_': 1331926831},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:5.0.1) Gecko/20100101 Firefox/5.0.1',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Wentzville',
#   u'g': u'vNJS4H',
#   u'gr': u'MO',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [38.790001, -90.854897],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926831,
#   u'tz': u'America/Chicago',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2',
#   u'al': u'en-us,en;q=0.5',
#   u'c': u'US',
#   u'cy': u'Saint Charles',
#   u'g': u'vNJS4H',
#   u'gr': u'IL',
#   u'h': u'u0uD9q',
#   u'hc': 1319563556,
#   u'hh': u'1.usa.gov',
#   u'l': u'o_4us71ccioa',
#   u'll': [41.9352, -88.290901],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926832,
#   u'tz': u'America/Chicago',
#   u'u': u'https://www.nysdot.gov/rexdesign/design/community.gif'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B179',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Los Angeles',
#   u'g': u'qMac9k',
#   u'gr': u'CA',
#   u'h': u'qds1Ge',
#   u'hc': 1310473559,
#   u'hh': u'1.usa.gov',
#   u'l': u'healthypeople',
#   u'll': [34.041599, -118.298798],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926833,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://healthypeople.gov/2020/connect/webinars.aspx'},
#  {u'a': u'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.52.7 (KHTML, like Gecko) Version/5.1.2 Safari/534.52.7',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Silver Spring',
#   u'g': u'y0jYkg',
#   u'gr': u'MD',
#   u'h': u'y0jYkg',
#   u'hc': 1331851811,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [39.052101, -77.014999],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926836,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.epa.gov/otaq/regs/fuels/additive/e15/documents/rfa-model-e15-mmp-letter.pdf'},
#  {u'a': u'Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko) Mobile/9B176 Twitter for iPhone',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Mcgehee',
#   u'g': u'y5rMac',
#   u'gr': u'AR',
#   u'h': u'xANY6O',
#   u'hc': 1331916302,
#   u'hh': u'1.usa.gov',
#   u'l': u'twitterfeed',
#   u'll': [33.628399, -91.356903],
#   u'nk': 1,
#   u'r': u'https://twitter.com/fdarecalls/status/180697594887012352',
#   u't': 1331926836,
#   u'tz': u'America/Chicago',
#   u'u': u'http://www.fda.gov/Safety/Recalls/ucm296326.htm'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'sv-SE,sv;q=0.8,en-US;q=0.6,en;q=0.4',
#   u'c': u'SE',
#   u'cy': u'Sollefte',
#   u'g': u'eH8wu',
#   u'gr': u'24',
#   u'h': u'7dtjei',
#   u'hc': 1260316355,
#   u'hh': u'1.usa.gov',
#   u'l': u'tweetdeckapi',
#   u'll': [63.166698, 17.266701],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926834,
#   u'tz': u'Europe/Stockholm',
#   u'u': u'http://www.nasa.gov/mission_pages/WISE/main/index.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; MS-RTC LM 8; .NET4.0C; AskTbORJ/5.14.1.20007; Judge)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Conshohocken',
#   u'g': u'A00b72',
#   u'gr': u'PA',
#   u'h': u'yGSwzn',
#   u'hc': 1331917632,
#   u'hh': u'1.usa.gov',
#   u'l': u'addthis',
#   u'll': [40.0798, -75.2855],
#   u'nk': 0,
#   u'r': u'http://www.linkedin.com/home?trk=hb_tab_home_top',
#   u't': 1331926837,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.nlm.nih.gov/medlineplus/news/fullstory_122801.html#.T2NzQMBzHzQ.twitter'},
#  {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': None,
#   u'g': u'wcndER',
#   u'h': u'zkpJBR',
#   u'hc': 1331922854,
#   u'hh': u'1.usa.gov',
#   u'l': u'bnjacobs',
#   u'nk': 0,
#   u'r': u'http://plus.url.google.com/url?sa=z&n=1331926863438&url=http%3A%2F%2F1.usa.gov%2FzkpJBR&usg=ADCzl1X8b5j1Vx2ZAPzpFi4DM_Q.',
#   u't': 1331926837,
#   u'tz': u'',
#   u'u': u'http://www.nasa.gov/mission_pages/nustar/main/index.html'},
#  {u'a': u'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.3) Gecko/20100405 Namoroka/3.6.3',
#   u'c': u'US',
#   u'cy': u'Decatur',
#   u'g': u'rqgJuE',
#   u'gr': u'AL',
#   u'h': u'xcz8vt',
#   u'hc': 1331227417,
#   u'hh': u'1.usa.gov',
#   u'l': u'bootsnall',
#   u'll': [34.572701, -86.940598],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331926839,
#   u'tz': u'America/Chicago',
#   u'u': u'http://travel.state.gov/passport/passport_5535.html'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.30618; .NET CLR 3.5.30729)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Shrewsbury',
#   u'g': u'9b6kNl',
#   u'gr': u'MA',
#   u'h': u'9b6kNl',
#   u'hc': 1273672411,
#   u'hh': u'bit.ly',
#   u'l': u'bitly',
#   u'll': [42.286499, -71.714699],
#   u'nk': 0,
#   u'r': u'http://www.shrewsbury-ma.gov/selco/',
#   u't': 1331926840,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.shrewsbury-ma.gov/egov/gallery/134127368672998.png'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.30618; .NET CLR 3.5.30729)',
#   u'al': u'en-us',
#   u'c': u'US',
#   u'cy': u'Shrewsbury',
#   u'g': u'axNK8c',
#   u'gr': u'MA',
#   u'h': u'axNK8c',
#   u'hc': 1273672506,
#   u'hh': u'bit.ly',
#   u'l': u'bitly',
#   u'll': [42.286499, -71.714699],
#   u'nk': 0,
#   u'r': u'http://www.shrewsbury-ma.gov/selco/',
#   u't': 1331926840,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.shrewsbury-ma.gov/egov/gallery/134127368675393.png'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
#   u'al': u'en',
#   u'c': u'US',
#   u'cy': u'Paramus',
#   u'g': u'e5SvKE',
#   u'gr': u'NJ',
#   u'h': u'fqPSr9',
#   u'hc': 1301298479,
#   u'hh': u'1.usa.gov',
#   u'l': u'tweetdeckapi',
#   u'll': [40.9445, -74.07],
#   u'nk': 1,
#   u'r': u'direct',
#   u't': 1331926841,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.fda.gov/AdvisoryCommittees/CommitteesMeetingMaterials/Drugs/Anti-InfectiveDrugsAdvisoryCommittee/ucm242307.htm'},
#  {u'a': u'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Oklahoma City',
#   u'g': u'jQLtP4',
#   u'gr': u'OK',
#   u'h': u'jQLtP4',
#   u'hc': 1307530247,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [35.4715, -97.518997],
#   u'nk': 0,
#   u'r': u'http://www.facebook.com/l.php?u=http%3A%2F%2F1.usa.gov%2FjQLtP4&h=3AQF8AIR_',
#   u't': 1331926844,
#   u'tz': u'America/Chicago',
#   u'u': u'http://www.okc.gov/PublicNotificationSystem/Forms/publicNotificationInformation.aspx?notificationID=55966dfa-52b9-48fb-865e-a775acf1e696'},
#  {u'a': u'GoogleMaps/RochesterNY',
#   u'c': u'US',
#   u'cy': u'Provo',
#   u'g': u'mwszkS',
#   u'gr': u'UT',
#   u'h': u'mwszkS',
#   u'hc': 1308262393,
#   u'hh': u'j.mp',
#   u'l': u'bitly',
#   u'll': [40.218102, -111.613297],
#   u'nk': 0,
#   u'r': u'http://www.AwareMap.com/',
#   u't': 1331926846,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.monroecounty.gov/etc/911/rss.php'},
#  {u'a': u'GoogleProducer',
#   u'c': u'US',
#   u'cy': u'Mountain View',
#   u'g': u'zjtI4X',
#   u'gr': u'CA',
#   u'h': u'zjtI4X',
#   u'hc': 1327528527,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [37.419201, -122.057404],
#   u'nk': 0,
#   u'r': u'direct',
#   u't': 1331926847,
#   u'tz': u'America/Los_Angeles',
#   u'u': u'http://www.ahrq.gov/qual/qitoolkit/'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; MS-RTC LM 8; .NET4.0C; .NET4.0E; .NET CLR 1.1.4322)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Mc Lean',
#   u'g': u'qxKrTK',
#   u'gr': u'VA',
#   u'h': u'qxKrTK',
#   u'hc': 1312897670,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [38.935799, -77.162102],
#   u'nk': 0,
#   u'r': u'http://t.co/OEEEvwjU',
#   u't': 1331926849,
#   u'tz': u'America/New_York',
#   u'u': u'http://herndon-va.gov/Content/public_safety/Public_Information/weekly_reports.aspx?cnlid=1736'}]

# %%
time_zones = [rec.get('tz',"LOL") for rec in records] #gives a value or gives none if doesn't exist ==> safeway of getting from dict
#time_zones = [rec['tz'] for rec in records] #what is the difference ??

time_zones
# Out:
# [u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'Asia/Hong_Kong',
#  u'Asia/Hong_Kong',
#  u'America/New_York',
#  u'America/Denver',
#  u'Europe/Rome',
#  u'Africa/Ceuta',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'Asia/Kuala_Lumpur',
#  u'Asia/Nicosia',
#  u'America/Sao_Paulo',
#  u'',
#  u'',
#  u'Europe/London',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/Chicago',
#  u'',
#  u'',
#  u'Pacific/Honolulu',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Malta',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Sao_Paulo',
#  u'',
#  u'Asia/Hong_Kong',
#  u'Asia/Hong_Kong',
#  u'Pacific/Honolulu',
#  u'Pacific/Honolulu',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  u'Europe/Lisbon',
#  u'Europe/Paris',
#  u'Europe/London',
#  u'Europe/Copenhagen',
#  u'',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'Europe/London',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/Paris',
#  u'America/Denver',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Mazatlan',
#  u'',
#  u'Europe/Dublin',
#  u'America/New_York',
#  u'Asia/Hong_Kong',
#  u'Asia/Hong_Kong',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/Brussels',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'America/Vancouver',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'Europe/Prague',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Stockholm',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/Anchorage',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Kuala_Lumpur',
#  u'',
#  u'',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Asia/Bangkok',
#  u'Europe/Berlin',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  'LOL',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/Chicago',
#  u'Europe/Warsaw',
#  u'America/Denver',
#  u'Europe/Warsaw',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Los_Angeles',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'America/Denver',
#  u'Europe/Berlin',
#  u'',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/Prague',
#  'LOL',
#  u'America/Denver',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Budapest',
#  u'Asia/Bangkok',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Anchorage',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Madrid',
#  u'Asia/Tokyo',
#  u'America/Denver',
#  u'Europe/London',
#  u'',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/Vienna',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'Europe/Lisbon',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'',
#  u'Pacific/Honolulu',
#  u'Pacific/Honolulu',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Rainy_River',
#  u'',
#  u'America/Chicago',
#  u'Asia/Jerusalem',
#  u'Europe/Dublin',
#  u'America/New_York',
#  u'Asia/Karachi',
#  u'America/Los_Angeles',
#  u'Pacific/Honolulu',
#  u'Europe/Vienna',
#  u'Pacific/Honolulu',
#  u'America/Chicago',
#  'LOL',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/Denver',
#  u'America/Bogota',
#  u'America/Indianapolis',
#  u'',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Montreal',
#  u'Asia/Calcutta',
#  u'America/New_York',
#  u'Europe/Stockholm',
#  u'Europe/Vienna',
#  u'America/Denver',
#  u'Europe/Lisbon',
#  u'Europe/London',
#  u'Europe/Vienna',
#  u'Europe/Amsterdam',
#  u'Europe/Skopje',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/Rainy_River',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'',
#  u'Europe/Prague',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'Europe/Berlin',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/Vancouver',
#  u'Europe/Madrid',
#  u'America/Indianapolis',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'Europe/Madrid',
#  u'Asia/Beirut',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'Australia/NSW',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  'LOL',
#  u'',
#  u'Europe/Budapest',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Vancouver',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'',
#  'LOL',
#  u'Europe/Madrid',
#  u'Europe/Paris',
#  u'America/New_York',
#  u'Asia/Karachi',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Europe/Berlin',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Chile/Continental',
#  u'',
#  u'America/Denver',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'',
#  u'',
#  u'America/Halifax',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Vancouver',
#  u'',
#  u'',
#  u'',
#  u'America/Denver',
#  u'',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'Europe/Madrid',
#  u'',
#  u'Pacific/Honolulu',
#  u'',
#  u'',
#  u'',
#  u'Pacific/Honolulu',
#  u'America/Indianapolis',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'Asia/Calcutta',
#  u'Europe/Stockholm',
#  'LOL',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'Europe/Warsaw',
#  u'America/Los_Angeles',
#  u'Europe/Amsterdam',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/Edmonton',
#  u'America/New_York',
#  'LOL',
#  u'America/Los_Angeles',
#  u'America/Phoenix',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Phoenix',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'Pacific/Honolulu',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/Brussels',
#  u'America/Denver',
#  u'Europe/Bratislava',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Recife',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Africa/Cairo',
#  u'America/New_York',
#  u'Asia/Istanbul',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'',
#  u'',
#  u'America/Vancouver',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'Asia/Tokyo',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'Pacific/Honolulu',
#  u'Europe/Berlin',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'Asia/Istanbul',
#  u'Europe/London',
#  u'Asia/Novosibirsk',
#  u'America/Los_Angeles',
#  u'',
#  'LOL',
#  u'America/Chicago',
#  u'America/Montreal',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'Pacific/Honolulu',
#  u'Asia/Istanbul',
#  u'America/New_York',
#  u'Asia/Bangkok',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'',
#  'LOL',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Moscow',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Vancouver',
#  u'America/Sao_Paulo',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Vancouver',
#  'LOL',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Sofia',
#  u'',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/Bogota',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'Africa/Cairo',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Asia/Tokyo',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Sao_Paulo',
#  u'America/Chicago',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'Europe/Ljubljana',
#  u'Asia/Tokyo',
#  u'Europe/Copenhagen',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'America/Mexico_City',
#  u'',
#  u'Europe/Helsinki',
#  u'Europe/Bucharest',
#  u'Asia/Tokyo',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'Europe/London',
#  u'Asia/Tokyo',
#  u'',
#  u'America/Denver',
#  u'America/Denver',
#  u'Europe/Zurich',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/Los_Angeles',
#  u'Asia/Istanbul',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'Europe/London',
#  u'America/Los_Angeles',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Mexico_City',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Puerto_Rico',
#  u'America/Puerto_Rico',
#  u'Asia/Tokyo',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/Rainy_River',
#  u'Asia/Tokyo',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Chicago',
#  u'Asia/Tokyo',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Moscow',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'',
#  u'America/Monterrey',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'Asia/Tokyo',
#  u'Europe/Moscow',
#  u'America/Mexico_City',
#  u'America/Los_Angeles',
#  u'',
#  'LOL',
#  u'Asia/Hong_Kong',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Asia/Hong_Kong',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Athens',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/Prague',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'',
#  u'Asia/Tokyo',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  'LOL',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Lisbon',
#  u'',
#  u'',
#  u'',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Asia/Hong_Kong',
#  u'Asia/Hong_Kong',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Winnipeg',
#  u'Europe/London',
#  u'Europe/Riga',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'',
#  u'Europe/Stockholm',
#  u'',
#  u'Asia/Tokyo',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'Europe/Bucharest',
#  u'Europe/Rome',
#  u'America/Chicago',
#  u'Europe/Rome',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  u'America/Mexico_City',
#  u'',
#  'LOL',
#  u'America/Los_Angeles',
#  u'Asia/Tokyo',
#  u'Asia/Tokyo',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'Chile/Continental',
#  u'Asia/Istanbul',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  u'Europe/London',
#  u'America/Los_Angeles',
#  u'America/Mexico_City',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'Pacific/Honolulu',
#  u'America/Los_Angeles',
#  u'',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'',
#  u'Europe/Paris',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  'LOL',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'Europe/Warsaw',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'Chile/Continental',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'',
#  u'Chile/Continental',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'Asia/Tokyo',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Argentina/Buenos_Aires',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Vienna',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Paris',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Asia/Tokyo',
#  u'',
#  u'America/Anchorage',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'Pacific/Honolulu',
#  u'Pacific/Honolulu',
#  'LOL',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Mexico_City',
#  u'Asia/Tokyo',
#  u'America/Chicago',
#  u'Europe/Athens',
#  u'America/New_York',
#  u'',
#  u'Asia/Tokyo',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Puerto_Rico',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Mexico_City',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/Denver',
#  'LOL',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'Europe/London',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'Europe/Copenhagen',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'Asia/Dubai',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'Europe/Paris',
#  u'Asia/Tokyo',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/Oslo',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'Asia/Tokyo',
#  u'America/Puerto_Rico',
#  u'America/Puerto_Rico',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Asia/Yekaterinburg',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'',
#  'LOL',
#  u'America/New_York',
#  u'Europe/Bratislava',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'Africa/Cairo',
#  u'America/Rainy_River',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'',
#  u'Europe/Rome',
#  u'Asia/Manila',
#  u'',
#  u'America/Indianapolis',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/London',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  'LOL',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/London',
#  u'America/Los_Angeles',
#  u'Europe/Madrid',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Europe/Prague',
#  u'',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'',
#  u'America/Sao_Paulo',
#  u'America/Denver',
#  u'America/New_York',
#  u'Asia/Bangkok',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Asia/Bangkok',
#  u'Pacific/Honolulu',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Berlin',
#  u'Europe/Moscow',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'Europe/Berlin',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Stockholm',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Sao_Paulo',
#  u'Europe/Stockholm',
#  u'Europe/Paris',
#  'LOL',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Mexico_City',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Zurich',
#  u'',
#  u'Europe/Brussels',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'',
#  u'Europe/Berlin',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'Europe/London',
#  u'',
#  u'America/Mexico_City',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Paris',
#  u'Europe/London',
#  u'',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  'LOL',
#  u'Europe/London',
#  u'America/Mexico_City',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'America/Sao_Paulo',
#  u'Australia/NSW',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  u'Europe/Athens',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/Berlin',
#  u'America/Denver',
#  u'Europe/Amsterdam',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Beirut',
#  u'America/New_York',
#  u'',
#  u'America/Caracas',
#  u'America/New_York',
#  u'Asia/Riyadh',
#  u'America/Denver',
#  u'America/Montevideo',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  'LOL',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Helsinki',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Argentina/Mendoza',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'',
#  u'Asia/Seoul',
#  u'America/Sao_Paulo',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Chicago',
#  u'Europe/Athens',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Mexico_City',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/Uzhgorod',
#  u'America/Edmonton',
#  u'America/Denver',
#  u'',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'Australia/Queensland',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Berlin',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'Asia/Istanbul',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'Europe/Belgrade',
#  u'',
#  u'',
#  u'America/New_York',
#  u'',
#  u'Europe/Prague',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Lisbon',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Halifax',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Vancouver',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Bogota',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  'LOL',
#  u'America/Costa_Rica',
#  u'',
#  u'Asia/Beirut',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/Denver',
#  u'America/Chicago',
#  u'',
#  u'America/Chicago',
#  u'',
#  u'America/Chicago',
#  u'America/Recife',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Denver',
#  u'America/Lima',
#  u'America/Los_Angeles',
#  u'Europe/Prague',
#  u'Europe/Lisbon',
#  u'America/New_York',
#  u'',
#  u'America/Mexico_City',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Dublin',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Pontianak',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'Europe/Stockholm',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Amsterdam',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Madrid',
#  u'America/Chicago',
#  'LOL',
#  u'Europe/London',
#  u'Europe/London',
#  u'Asia/Tokyo',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'Europe/Paris',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Chicago',
#  u'',
#  'LOL',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Asia/Bangkok',
#  u'America/Edmonton',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Chicago',
#  u'Europe/London',
#  u'Pacific/Honolulu',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Montreal',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Montreal',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'Europe/London',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Malta',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'America/Chicago',
#  u'Asia/Calcutta',
#  u'',
#  u'America/Indianapolis',
#  u'',
#  u'America/New_York',
#  u'Chile/Continental',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Oslo',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'',
#  u'Asia/Jerusalem',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  'LOL',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Phoenix',
#  u'America/Denver',
#  u'America/Chihuahua',
#  u'Europe/Vilnius',
#  u'',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Los_Angeles',
#  u'Europe/Berlin',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Managua',
#  u'Asia/Beirut',
#  u'Europe/Berlin',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'Asia/Istanbul',
#  u'America/Chicago',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Chicago',
#  u'America/Denver',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Managua',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Africa/Lusaka',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Vancouver',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  'LOL',
#  u'America/New_York',
#  u'America/Denver',
#  u'Europe/Prague',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'America/Halifax',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/Oslo',
#  u'America/Los_Angeles',
#  u'Europe/Prague',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/Denver',
#  u'Europe/Paris',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'America/Managua',
#  u'Europe/Athens',
#  u'America/Denver',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  'LOL',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Chicago',
#  u'America/Denver',
#  u'Europe/London',
#  u'America/Denver',
#  u'Europe/London',
#  u'Europe/London',
#  u'',
#  u'',
#  u'America/Rainy_River',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Montreal',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Bratislava',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Athens',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'America/Guayaquil',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Indianapolis',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Halifax',
#  u'',
#  u'',
#  u'America/New_York',
#  'LOL',
#  u'Australia/NSW',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Asia/Calcutta',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Guayaquil',
#  u'America/Chicago',
#  u'',
#  u'Europe/Warsaw',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Asia/Istanbul',
#  u'America/Rainy_River',
#  u'America/Los_Angeles',
#  u'',
#  u'America/Denver',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'America/Denver',
#  u'Europe/Madrid',
#  u'',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'Europe/London',
#  u'America/Chicago',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'',
#  u'Asia/Harbin',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/Chicago',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Winnipeg',
#  u'Europe/Stockholm',
#  u'',
#  u'',
#  u'Europe/Amsterdam',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'Europe/London',
#  u'Europe/Brussels',
#  u'America/Denver',
#  u'America/Chicago',
#  u'Europe/Vilnius',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Rome',
#  u'America/Chicago',
#  'LOL',
#  u'America/Los_Angeles',
#  u'Europe/Helsinki',
#  u'Europe/Copenhagen',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Lisbon',
#  u'Europe/Amsterdam',
#  u'America/New_York',
#  u'Asia/Amman',
#  u'',
#  u'Europe/Amsterdam',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Indianapolis',
#  u'America/Sao_Paulo',
#  u'America/Los_Angeles',
#  u'Europe/London',
#  u'',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Oslo',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  'LOL',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'Asia/Amman',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Winnipeg',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Warsaw',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'Australia/NSW',
#  u'Asia/Calcutta',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'Europe/Belgrade',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Winnipeg',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/London',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'Asia/Calcutta',
#  u'America/Los_Angeles',
#  u'Africa/Johannesburg',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'Europe/Bucharest',
#  u'America/Montreal',
#  u'America/New_York',
#  u'America/Montreal',
#  u'America/St_Kitts',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Sao_Paulo',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Asia/Harbin',
#  u'',
#  u'America/New_York',
#  'LOL',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Pacific/Auckland',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'Europe/Amsterdam',
#  u'America/Denver',
#  u'Asia/Calcutta',
#  u'Europe/London',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'Pacific/Auckland',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Berlin',
#  u'America/Chicago',
#  u'',
#  u'Chile/Continental',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Santo_Domingo',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  'LOL',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'Pacific/Auckland',
#  u'America/New_York',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/Denver',
#  u'America/New_York',
#  'LOL',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Mexico_City',
#  u'Pacific/Honolulu',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Oslo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Denver',
#  u'America/Argentina/Cordoba',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/Rome',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/Phoenix',
#  u'America/Edmonton',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Sao_Paulo',
#  u'',
#  u'America/New_York',
#  u'America/Vancouver',
#  u'America/Montreal',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'Pacific/Auckland',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Denver',
#  u'America/Rainy_River',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'Pacific/Honolulu',
#  u'America/Rainy_River',
#  u'America/Montreal',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  'LOL',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Denver',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/New_York',
# ...
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Indianapolis',
#  u'',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Kuching',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'Europe/Madrid',
#  'LOL',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'Europe/Budapest',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Edmonton',
#  u'',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'America/Sao_Paulo',
#  u'',
#  u'',
#  u'Europe/Helsinki',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'',
#  u'America/New_York',
#  u'Asia/Harbin',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'Asia/Istanbul',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'America/Los_Angeles',
#  u'Europe/Paris',
#  u'Pacific/Honolulu',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'Pacific/Auckland',
#  u'America/New_York',
#  u'America/New_York',
#  u'Pacific/Auckland',
#  u'Pacific/Auckland',
#  u'America/Los_Angeles',
#  u'Pacific/Auckland',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'Europe/London',
#  'LOL',
#  u'Europe/Zurich',
#  u'Europe/Amsterdam',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Asia/Kuala_Lumpur',
#  u'Europe/Bucharest',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Europe/Helsinki',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Vancouver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Riga',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'',
#  u'Europe/Oslo',
#  u'America/New_York',
#  u'America/Mexico_City',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Dubai',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/New_York',
#  u'America/Indianapolis',
#  u'America/Denver',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'Pacific/Honolulu',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'Europe/Budapest',
#  u'Pacific/Auckland',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Madrid',
#  u'America/Mexico_City',
#  u'America/New_York',
#  u'Asia/Calcutta',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Moscow',
#  u'',
#  u'',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Africa/Ceuta',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/Chicago',
#  u'',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  'LOL',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Chicago',
#  u'',
#  u'America/Los_Angeles',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'Europe/Volgograd',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'',
#  u'America/Chicago',
#  u'Europe/London',
#  u'America/New_York',
#  u'Europe/Lisbon',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'Europe/Helsinki',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Tokyo',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'America/Denver',
#  u'',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Madrid',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'Europe/Amsterdam',
#  u'America/Indianapolis',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Oslo',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  'LOL',
#  u'Europe/London',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/Anchorage',
#  u'',
#  u'America/New_York',
#  u'America/La_Paz',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Moscow',
#  u'',
#  u'America/Chihuahua',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'Europe/Vienna',
#  u'America/New_York',
#  'LOL',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'America/Los_Angeles',
#  u'Africa/Casablanca',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'Asia/Dubai',
#  u'America/Los_Angeles',
#  u'Europe/Amsterdam',
#  u'America/Chicago',
#  'LOL',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Asia/Seoul',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'Europe/Moscow',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Vancouver',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Indianapolis',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  'LOL',
#  u'Europe/Helsinki',
#  u'America/New_York',
#  u'Asia/Seoul',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Copenhagen',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/Denver',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'Australia/NSW',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/New_York',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'Europe/Stockholm',
#  u'Europe/Stockholm',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/London',
#  u'America/Denver',
#  u'Europe/Helsinki',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Stockholm',
#  u'Europe/Paris',
#  u'',
#  'LOL',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'Europe/Prague',
#  u'America/Chicago',
#  u'',
#  'LOL',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/Denver',
#  u'Europe/Stockholm',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'Europe/London',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'',
#  u'America/Chicago',
#  u'Australia/NSW',
#  u'America/Chicago',
#  'LOL',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/London',
#  u'Europe/Oslo',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Denver',
#  u'Europe/Madrid',
#  u'Europe/London',
#  u'America/Chicago',
#  u'',
#  u'America/Chicago',
#  'LOL',
#  u'America/Chicago',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'Europe/Paris',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  'LOL',
#  u'America/New_York',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'Europe/Budapest',
#  'LOL',
#  u'Europe/Berlin',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Oslo',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Asia/Jakarta',
#  u'America/Edmonton',
#  u'America/Los_Angeles',
#  u'Europe/Moscow',
#  u'America/Phoenix',
#  u'Asia/Jakarta',
#  u'America/Chicago',
#  u'',
#  u'',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Madrid',
#  'LOL',
#  u'America/New_York',
#  u'America/Indianapolis',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'Europe/Amsterdam',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/New_York',
#  'LOL',
#  u'America/Denver',
#  u'',
#  u'Europe/Amsterdam',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'Europe/Amsterdam',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'Europe/Madrid',
#  u'Asia/Jakarta',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/Rainy_River',
#  u'America/Chicago',
#  u'America/New_York',
#  u'',
#  u'',
#  'LOL',
#  u'',
#  u'America/Phoenix',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Asia/Jerusalem',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'Europe/Paris',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  'LOL',
#  u'America/Denver',
#  u'',
#  u'America/New_York',
#  u'',
#  u'Europe/Berlin',
#  u'America/New_York',
#  u'America/Phoenix',
#  u'',
#  u'',
#  u'America/New_York',
#  u'',
#  u'America/Anchorage',
#  u'America/Denver',
#  u'Europe/London',
#  u'America/Chicago',
#  u'Europe/Helsinki',
#  u'',
#  'LOL',
#  u'America/New_York',
#  u'America/Chicago',
#  u'',
#  u'Asia/Karachi',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'Europe/Moscow',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'',
#  'LOL',
#  u'',
#  u'America/Denver',
#  u'America/New_York',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'',
#  u'Europe/Oslo',
#  u'',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Helsinki',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'',
#  u'America/Indianapolis',
#  u'Pacific/Honolulu',
#  u'',
#  u'Asia/Seoul',
#  u'Europe/London',
#  u'America/New_York',
#  'LOL',
#  u'Europe/Amsterdam',
#  u'',
#  u'America/New_York',
#  u'',
#  u'',
#  u'',
#  u'Asia/Seoul',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Denver',
#  u'America/Chicago',
#  u'America/Denver',
#  u'',
#  u'',
#  u'Asia/Dubai',
#  u'Europe/Madrid',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  'LOL',
#  u'Europe/Stockholm',
#  u'America/Denver',
#  u'America/New_York',
#  u'Europe/Rome',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Los_Angeles',
#  u'',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'',
#  u'America/Tegucigalpa',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/Los_Angeles',
#  'LOL',
#  u'America/Chicago',
#  u'America/Chicago',
#  u'America/Los_Angeles',
#  u'America/New_York',
#  u'America/Chicago',
#  u'Europe/Stockholm',
#  u'America/New_York',
#  u'',
#  u'America/Chicago',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/New_York',
#  u'America/Chicago',
#  u'America/Denver',
#  u'America/Los_Angeles',
#  u'America/New_York']

# %% [markdown]
# ## Jumping to "Counting Time Zones with pandas" (p.21)

# %%
from pandas import DataFrame, Series
import pandas as pd

# %%
# dataframe records is a list of dicts
# for eg:
df = DataFrame({'int_col' : [1,2,6,8,-1], 'float_col' : [0.1, 0.2,0.2,10.1,None], 'str_col' : ['a','b',None,'c','a']})
df
# Out:
#   float_col  int_col str_col
# 0       0.1        1       a
# 1       0.2        2       b
# 2       0.2        6    None
# 3      10.1        8       c
# 4      None       -1       a

# %%
frame['tz'].value_counts()
# Out:
# America/New_York        1251
#                          521
# America/Chicago          400
# America/Los_Angeles      382
# America/Denver           191
# Europe/London             74
# Asia/Tokyo                37
# Pacific/Honolulu          36
# Europe/Madrid             35
# America/Sao_Paulo         33
# Europe/Berlin             28
# Europe/Rome               27
# America/Rainy_River       25
# Europe/Amsterdam          22
# America/Indianapolis      20
# ...
# Europe/Ljubljana       1
# Asia/Riyadh            1
# Asia/Manila            1
# Africa/Casablanca      1
# Africa/Johannesburg    1
# Asia/Yekaterinburg     1
# America/Lima           1
# Asia/Kuching           1
# Africa/Lusaka          1
# America/Tegucigalpa    1
# America/La_Paz         1
# Asia/Nicosia           1
# Europe/Uzhgorod        1
# America/Costa_Rica     1
# America/Montevideo     1
# Length: 97, dtype: int64

# %%
# fill missing


clean_tz = frame['tz'].fillna('Missing')
clean_tz.value_counts()
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Europe/Berlin            28
# Europe/Rome              27
# America/Rainy_River      25
# Europe/Amsterdam         22
# ...
# Europe/Ljubljana       1
# Asia/Riyadh            1
# Asia/Manila            1
# Africa/Casablanca      1
# Africa/Johannesburg    1
# Asia/Yekaterinburg     1
# America/Lima           1
# Asia/Kuching           1
# Africa/Lusaka          1
# America/Tegucigalpa    1
# America/La_Paz         1
# Asia/Nicosia           1
# Europe/Uzhgorod        1
# America/Costa_Rica     1
# America/Montevideo     1
# Length: 98, dtype: int64

# %%
clean_tz[clean_tz==''] = 'Unknown'

# %%
clean_tz.value_counts()
# Out:
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Europe/Berlin            28
# Europe/Rome              27
# America/Rainy_River      25
# Europe/Amsterdam         22
# ...
# Europe/Ljubljana       1
# Asia/Riyadh            1
# Asia/Manila            1
# Africa/Casablanca      1
# Africa/Johannesburg    1
# Asia/Yekaterinburg     1
# America/Lima           1
# Asia/Kuching           1
# Africa/Lusaka          1
# America/Tegucigalpa    1
# America/La_Paz         1
# Asia/Nicosia           1
# Europe/Uzhgorod        1
# America/Costa_Rica     1
# America/Montevideo     1
# Length: 98, dtype: int64

# %%
# let's embed the plot inline
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tz_counts = clean_tz.value_counts()

# %%
tz_counts[:10].plot(kind='barh', rot=0)

# %% [markdown]
# And so on....
